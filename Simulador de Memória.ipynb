# %% [markdown]
# <h1> Memória </h1>
# <h2> Endereço de 4 bits, células de 8 bits. <h2/>

# %% [markdown]
# * Com o endereço de 4 bits, ficamos com um total de 16 possibilidades de endereço. (2^4 = 16)

# %% [markdown]
#     Tendo isso em vista, foi criada uma lista com 16 elementos, que fará o papel da memória.
#     Dependendo da operação selecionada, esses elementos podem ser lidos ou substituidos, como seria numa memória de verdade.

# %%
def Conversor(n):
    valor = 0
    a = 3
    for x in n:
        y = int(x)*(2**a)
        valor += y
        a -= 1
    return valor

L = ['00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000', '00000000']
print('='*10, 'Memória Principal', '='*10)
while True:
    print('='*39)
    print('Você pode ler, escrever, ver estado atual ou sair da memória.')
    print('Use E para escrever, L para apenas ler, A para o estado atual e S para sair.')
    op = input('Operação [E, L, A ou S]: ')
    if (op == 'E'):
        end = input('Digite o endereço (4 bits): ')
        número = input('E qual seria o valor a ser substituido? (8 bits) ')
        pos = Conversor(end)
        L[pos] = número
    elif (op == 'L'):
        end = input('Digite o endereço (4 bits): ')
        pos = Conversor(end)
        print('O dado no endereço concedido é: {}'.format(L[pos]))
    elif (op == 'A'):
        print('')
        print('Memória Atual:')
        for z in L :
            print('-'*10, z, '-'*10)
    elif (op == 'S'):
        break
    else:
        print('Operação inválida! Tente de novo.')
# Out:
# ========== Memória Principal ==========
# ...
# Você pode ler, escrever, ver estado atual ou sair da memória.
# Use E para escrever, L para apenas ler, A para o estado atual e S para sair.
# Operação [E, L, A ou S]: a
# Operação inválida! Tente de novo.
# ...
# Você pode ler, escrever, ver estado atual ou sair da memória.
# Use E para escrever, L para apenas ler, A para o estado atual e S para sair.
# Operação [E, L, A ou S]: A
#
# Memória Atual:
# ---------- 00000000 ----------
# ---------- 00000000 ----------
# ---------- 00000000 ----------
# ---------- 00000000 ----------
# ---------- 00000000 ----------
# ---------- 00000000 ----------
# ---------- 00000000 ----------
# ---------- 00000000 ----------
# ---------- 00000000 ----------
# ---------- 00000000 ----------
# ---------- 00000000 ----------
# ---------- 00000000 ----------
# ---------- 00000000 ----------
# ---------- 00000000 ----------
# ---------- 00000000 ----------
# ---------- 00000000 ----------
# ...

# %% [markdown]
# <h3> Acima foram vistos vários exemplos da memória em funcionamento. A operação de Escrever é destrutiva, substituindo o valor anterior que fica perdido para sempre, diferentemente da operação Escrever. Nesta, o valor do endereço dado é apenas mostrado e a memória permanece intacta. <h3/>
